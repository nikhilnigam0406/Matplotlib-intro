# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import random

# %%
ml_students_age = np.random.randint(12,95,(100))
py_students = np.random.randint(11,80,(100))

# %%
print(ml_students_age)
print(py_students)
# Out:
# [30 80 93 50 55 75 69 17 25 77 34 81 29 69 19 94 45 37 79 53 89 44 63 33
#  30 74 22 51 72 36 76 57 84 89 22 73 88 45 64 53 73 80 39 78 74 18 30 17
#  87 66 35 12 92 35 29 53 79 58 50 71 22 55 83 74 61 83 82 30 88 92 29 68
#  72 76 49 87 36 50 64 90 69 69 35 28 36 93 21 17 65 59 44 39 64 42 83 17
#  33 65 69 51]
# [24 49 32 68 77 44 71 33 68 57 55 60 74 23 16 13 71 51 65 70 24 58 44 12
#  63 37 38 78 41 30 46 71 49 67 78 27 14 59 45 49 61 64 30 28 43 65 39 25
#  55 75 53 75 47 13 36 38 27 58 20 64 74 63 13 68 18 67 41 69 34 20 71 66
#  25 13 44 26 41 72 70 59 28 30 65 33 36 50 29 31 34 54 59 57 51 30 25 59
#  45 68 70 18]

# %%
#drow
plt.hist(ml_students_age)
plt.xlabel("Students are histogram")
plt.ylabel("No. students age")
plt.show()

# %%
bins = [15,20,25,30,35,40,45,50,55,60]
plt.hist(ml_students_age,bins, rwidth = 0.8, histtype = "bar", orientation = 'horizontal',color = 'g', label = "M L student", )
plt.xlabel("Students are histogram")
plt.ylabel("No. students age")
plt.legend()
plt.show()
